# %% [markdown]
# # pit-perfect
# Exploration of strategy choice during the 2024 Brazillian Grand Prix. This race was incredibly diverse in strategy with many stories within. Who did what they could during safety car restarts, and who ight have failed to capitalise on optimal pit windows?
#
# Why? F1 interests me in many ways. Look to Piere Gasley's maiden win and more recently Hulkenburg's surprise podium late in his career. Although fortuitous circumstances aided in their respective achievements, generally, strategy comes down to pitting at the right moment. Maintaining pace and keeping track position.
#
# What I hope to learn: Increase my comfortability working with Python and analysing somewhat disconnected and messy data sets from API's and other sources. I was also curious watching this race what on earth was going on strategy wise and how the teams managed their races.

# %% [markdown]
# ## 1. Preliminaries

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# Import libraries
import pandas as pd
import requests
from datetime import datetime
import json

# %% [markdown]
# ### 1.2 Import Data

# %%
lap_times_df = pd.read_csv('data/lap_times.csv')
circuits_df = pd.read_csv('data/circuits.csv')
races_df = pd.read_csv('data/races.csv')
drivers_df = pd.read_csv('data/drivers.csv')
pit_stops_df = pd.read_csv('data/drivers.csv')

# circuits (circuitId) <- races (raceId) <- lap_times -> drivers (driverId)

# %% [markdown]
# ### 1.3 Extract Lap Times
# As the weather API has no lap-by-lap data, we need to do this manually and map to each lap time.
# As for the lap data, there is no API which provides time stamps for each lap start time, so we will extract these from the lap data ourselves.
# Fortunately, this is quite simple to do. In a race, the leader determines when the next lap starts, so all we need to do is for each lap, find the earliest time, and this is the time that lap begun. From there we will approximate to the weather data the closest time and connect these features to provide approximate lap-by-lap weather.

# %%
# Get meeting and session details for Brazillian Grand Prix 2024
location = "Brazil"
year = 2024
url = f"https://api.openf1.org/v1/sessions?country_name={location}&session_name=Race&year={year}"
session_details_response = requests.get(url).json()
meeting = session_details_response[0]["meeting_key"]
session = session_details_response[0]["session_key"]
print(f"Meeting Key ({meeting}), Session Key ({session})")
# Out:
# Meeting Key (1249), Session Key (9636)

# %%
# Get raw lap data
url = f"https://api.openf1.org/v1/laps?session_key={session}"
lap_data_response = requests.get(url).json()
df_laps = pd.DataFrame(lap_data_response)
df_laps.sample(n=3)
# Out:
#       meeting_key  session_key  driver_number  lap_number  \
# 730          1249         9636             50          42
# 1125         1249         9636             16          69
# 1115         1249         9636             44          68
#
#                             date_start  duration_sector_1  duration_sector_2  \
# 730   2024-11-03T17:18:02.147000+00:00             26.293             58.854
# 1125  2024-11-03T17:55:59.569000+00:00             21.186             43.692
# 1115  2024-11-03T17:54:59.074000+00:00             21.202             42.957
#
#       duration_sector_3  i1_speed  i2_speed  is_pit_out_lap  lap_duration  \
# 730              34.787     188.0     110.0           False       119.934
# 1125             18.116     303.0     228.0           False        82.994
# 1115             17.945     306.0     229.0           False        82.104
#
#                                segments_sector_1  \
# 730   [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 1125  [None, 2048, 2048, 2048, 2048, 2048, 2048]
# 1115  [2048, 2049, 2048, 2048, 2048, 2048, 2048]
#
#                                      segments_sector_2  \
# 730   [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 1125  [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]
# 1115  [2048, 2048, 2051, 2049, 2048, 2049, 2048, 2048]
#
#                    segments_sector_3  st_speed
# 730   [2048, 2048, 2048, 2048, 2048]     175.0
# 1125  [2048, 2048, 2048, 2048, 2048]     293.0
# 1115  [2048, 2048, 2048, 2048, 2048]     277.0

# %%
# Now we need to get only the earliest lap which in effect gives us the time the lap started
leader_laps = df_laps.groupby('lap_number', as_index=False).agg({'date_start': 'min'})
leader_laps.rename(columns={"date_start": "lap_date_start"}, inplace=True)
leader_laps.loc[0, "lap_date_start"] = "2024-11-03T15:50:00.000000+00:00" # Race start time
leader_laps['lap_date_start'] = pd.to_datetime(leader_laps['lap_date_start'])
leader_laps.head(n=3)
# Out:
#    lap_number                   lap_date_start
# 0           1        2024-11-03 15:50:00+00:00
# 1           2 2024-11-03 15:51:28.489000+00:00
# 2           3 2024-11-03 15:52:54.148000+00:00

# %% [markdown]
# ### 1.4 Retrieve Weather Data

# %%
# Now we can query for the weather data during the event
url = f"https://api.openf1.org/v1/weather?meeting_key={meeting}&session_key={session}"
response = requests.get(url).json()
response
# Out:
# [{'date': '2024-11-03T14:38:25.648000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 27.3,
#   'humidity': 86.0,
#   'pressure': 927.4,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:39:25.648000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 26.2,
#   'humidity': 87.0,
#   'pressure': 927.3,
#   'wind_direction': 191,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:40:25.648000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 26.4,
#   'humidity': 86.0,
#   'pressure': 927.4,
#   'wind_direction': 182,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:41:25.651000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 26.4,
#   'humidity': 87.0,
#   'pressure': 927.4,
#   'wind_direction': 210,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:42:25.655000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 26.2,
#   'humidity': 87.0,
#   'pressure': 927.3,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:43:25.660000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 26.2,
#   'humidity': 87.0,
#   'pressure': 927.4,
#   'wind_direction': 215,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:44:25.666000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 26.4,
#   'humidity': 88.0,
#   'pressure': 927.3,
#   'wind_direction': 205,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:45:25.649000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 26.4,
#   'humidity': 86.0,
#   'pressure': 927.4,
#   'wind_direction': 242,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:46:25.665000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 26.4,
#   'humidity': 87.0,
#   'pressure': 927.3,
#   'wind_direction': 210,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:47:25.650000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 26.5,
#   'humidity': 88.0,
#   'pressure': 927.3,
#   'wind_direction': 240,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:48:25.669000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 26.8,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 216,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:49:25.652000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 26.9,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 208,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:50:25.669000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 27.2,
#   'humidity': 87.0,
#   'pressure': 927.3,
#   'wind_direction': 201,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:51:25.662000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 27.4,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 234,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:52:25.663000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 27.4,
#   'humidity': 88.0,
#   'pressure': 927.3,
#   'wind_direction': 179,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:53:25.666000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 27.4,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 195,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:54:25.658000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.4,
#   'track_temperature': 27.9,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 227,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:55:25.675000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.4,
#   'track_temperature': 27.7,
#   'humidity': 87.0,
#   'pressure': 927.1,
#   'wind_direction': 339,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:56:25.671000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 27.6,
#   'humidity': 87.0,
#   'pressure': 927.2,
#   'wind_direction': 348,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T14:57:25.676000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 27.7,
#   'humidity': 87.0,
#   'pressure': 927.1,
#   'wind_direction': 313,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T14:58:25.671000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 27.8,
#   'humidity': 88.0,
#   'pressure': 927.2,
#   'wind_direction': 317,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T14:59:25.657000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 28.3,
#   'humidity': 87.0,
#   'pressure': 927.1,
#   'wind_direction': 295,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:00:25.671000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 28.2,
#   'humidity': 87.0,
#   'pressure': 927.1,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:01:25.672000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 28.0,
#   'humidity': 87.0,
#   'pressure': 927.1,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:02:25.695000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.7,
#   'track_temperature': 28.2,
#   'humidity': 86.0,
#   'pressure': 927.0,
#   'wind_direction': 170,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:03:25.696000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 28.5,
#   'humidity': 88.0,
#   'pressure': 927.1,
#   'wind_direction': 30,
#   'meeting_key': 1249,
#   'wind_speed': 0.3,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:04:25.690000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.7,
#   'track_temperature': 28.7,
#   'humidity': 84.0,
#   'pressure': 927.0,
#   'wind_direction': 11,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:05:25.689000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 29.1,
#   'humidity': 85.0,
#   'pressure': 927.1,
#   'wind_direction': 37,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:06:25.696000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.6,
#   'track_temperature': 29.1,
#   'humidity': 84.0,
#   'pressure': 927.1,
#   'wind_direction': 178,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:07:25.735000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.7,
#   'track_temperature': 29.1,
#   'humidity': 82.0,
#   'pressure': 927.1,
#   'wind_direction': 303,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:08:25.710000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.9,
#   'track_temperature': 29.1,
#   'humidity': 85.0,
#   'pressure': 927.0,
#   'wind_direction': 220,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:09:25.716000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.9,
#   'track_temperature': 29.1,
#   'humidity': 82.0,
#   'pressure': 927.1,
#   'wind_direction': 275,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:10:25.736000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.8,
#   'track_temperature': 29.0,
#   'humidity': 82.0,
#   'pressure': 927.0,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:11:25.757000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.9,
#   'track_temperature': 29.4,
#   'humidity': 84.0,
#   'pressure': 927.0,
#   'wind_direction': 214,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:12:25.762000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.9,
#   'track_temperature': 29.5,
#   'humidity': 82.0,
#   'pressure': 927.0,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:13:25.775000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.4,
#   'humidity': 83.0,
#   'pressure': 927.0,
#   'wind_direction': 330,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:14:25.790000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.4,
#   'humidity': 80.0,
#   'pressure': 927.0,
#   'wind_direction': 288,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:15:25.799000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.4,
#   'humidity': 81.0,
#   'pressure': 927.0,
#   'wind_direction': 272,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:16:25.803000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.4,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 221,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:17:25.805000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.4,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 193,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:18:25.802000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 29.3,
#   'humidity': 80.0,
#   'pressure': 926.9,
#   'wind_direction': 239,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:19:25.804000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.1,
#   'track_temperature': 29.0,
#   'humidity': 80.0,
#   'pressure': 926.9,
#   'wind_direction': 266,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:20:25.800000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.1,
#   'track_temperature': 28.5,
#   'humidity': 80.0,
#   'pressure': 926.9,
#   'wind_direction': 241,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:21:25.800000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.6,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 218,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:22:25.817000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.2,
#   'track_temperature': 28.5,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 197,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:23:25.801000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.2,
#   'track_temperature': 28.5,
#   'humidity': 81.0,
#   'pressure': 926.9,
#   'wind_direction': 214,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:24:25.817000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.5,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 221,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:25:25.820000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.8,
#   'humidity': 82.0,
#   'pressure': 926.8,
#   'wind_direction': 215,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:26:25.812000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.4,
#   'track_temperature': 28.8,
#   'humidity': 80.0,
#   'pressure': 926.9,
#   'wind_direction': 184,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:27:25.813000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.5,
#   'humidity': 80.0,
#   'pressure': 926.8,
#   'wind_direction': 206,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:28:25.818000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.2,
#   'track_temperature': 28.4,
#   'humidity': 82.0,
#   'pressure': 926.9,
#   'wind_direction': 207,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:29:25.819000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.2,
#   'track_temperature': 28.4,
#   'humidity': 81.0,
#   'pressure': 926.9,
#   'wind_direction': 207,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:30:25.820000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.6,
#   'humidity': 81.0,
#   'pressure': 926.8,
#   'wind_direction': 233,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:31:25.820000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.6,
#   'humidity': 81.0,
#   'pressure': 926.8,
#   'wind_direction': 195,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:32:25.822000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 28.2,
#   'humidity': 81.0,
#   'pressure': 926.8,
#   'wind_direction': 192,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:33:25.814000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 27.9,
#   'humidity': 80.0,
#   'pressure': 926.7,
#   'wind_direction': 216,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:34:25.822000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.3,
#   'track_temperature': 27.9,
#   'humidity': 80.0,
#   'pressure': 926.8,
#   'wind_direction': 133,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:35:25.823000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.2,
#   'track_temperature': 27.9,
#   'humidity': 81.0,
#   'pressure': 926.7,
#   'wind_direction': 145,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:36:25.821000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.1,
#   'track_temperature': 27.1,
#   'humidity': 80.0,
#   'pressure': 926.7,
#   'wind_direction': 200,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:37:25.817000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.1,
#   'track_temperature': 26.9,
#   'humidity': 80.0,
#   'pressure': 926.7,
#   'wind_direction': 183,
#   'meeting_key': 1249,
#   'wind_speed': 1.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:38:25.829000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 26.0,
#   'humidity': 79.0,
#   'pressure': 926.6,
#   'wind_direction': 199,
#   'meeting_key': 1249,
#   'wind_speed': 1.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:39:25.821000+00:00',
#   'session_key': 9636,
#   'air_temperature': 23.0,
#   'track_temperature': 25.9,
#   'humidity': 80.0,
#   'pressure': 926.7,
#   'wind_direction': 181,
#   'meeting_key': 1249,
#   'wind_speed': 1.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:40:25.821000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.9,
#   'track_temperature': 25.6,
#   'humidity': 81.0,
#   'pressure': 926.7,
#   'wind_direction': 177,
#   'meeting_key': 1249,
#   'wind_speed': 1.3,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:41:25.826000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.8,
#   'track_temperature': 25.4,
#   'humidity': 81.0,
#   'pressure': 926.6,
#   'wind_direction': 203,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:42:25.822000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.8,
#   'track_temperature': 25.4,
#   'humidity': 81.0,
#   'pressure': 926.6,
#   'wind_direction': 200,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:43:25.822000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.7,
#   'track_temperature': 25.5,
#   'humidity': 82.0,
#   'pressure': 926.6,
#   'wind_direction': 181,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:44:25.830000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.5,
#   'humidity': 81.0,
#   'pressure': 926.5,
#   'wind_direction': 187,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:45:25.824000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.2,
#   'humidity': 79.0,
#   'pressure': 926.5,
#   'wind_direction': 187,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:46:25.838000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.2,
#   'humidity': 80.0,
#   'pressure': 926.5,
#   'wind_direction': 189,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:47:25.824000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.4,
#   'humidity': 80.0,
#   'pressure': 926.6,
#   'wind_direction': 203,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:48:25.823000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.4,
#   'humidity': 79.0,
#   'pressure': 926.5,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:49:25.819000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.1,
#   'humidity': 79.0,
#   'pressure': 926.6,
#   'wind_direction': 197,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T15:50:25.826000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.5,
#   'track_temperature': 25.1,
#   'humidity': 78.0,
#   'pressure': 926.6,
#   'wind_direction': 259,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:51:25.830000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.4,
#   'track_temperature': 25.0,
#   'humidity': 78.0,
#   'pressure': 926.6,
#   'wind_direction': 173,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:52:25.830000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.4,
#   'track_temperature': 24.6,
#   'humidity': 78.0,
#   'pressure': 926.6,
#   'wind_direction': 265,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:53:25.832000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.4,
#   'track_temperature': 24.6,
#   'humidity': 78.0,
#   'pressure': 926.7,
#   'wind_direction': 72,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:54:25.838000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 24.5,
#   'humidity': 78.0,
#   'pressure': 926.5,
#   'wind_direction': 187,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:55:25.838000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 24.4,
#   'humidity': 77.0,
#   'pressure': 926.6,
#   'wind_direction': 188,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:56:25.839000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 24.6,
#   'humidity': 78.0,
#   'pressure': 926.6,
#   'wind_direction': 201,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:57:25.842000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 24.8,
#   'humidity': 79.0,
#   'pressure': 926.5,
#   'wind_direction': 227,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:58:25.843000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 24.9,
#   'humidity': 78.0,
#   'pressure': 926.6,
#   'wind_direction': 191,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T15:59:25.842000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 24.9,
#   'humidity': 77.0,
#   'pressure': 926.6,
#   'wind_direction': 330,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:00:25.829000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 24.9,
#   'humidity': 78.0,
#   'pressure': 926.5,
#   'wind_direction': 268,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:01:25.896000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 25.0,
#   'humidity': 78.0,
#   'pressure': 926.5,
#   'wind_direction': 213,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:02:25.831000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 25.0,
#   'humidity': 77.0,
#   'pressure': 926.6,
#   'wind_direction': 170,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:03:25.849000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 25.0,
#   'humidity': 77.0,
#   'pressure': 926.5,
#   'wind_direction': 227,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:04:25.844000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 24.9,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 189,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:05:25.843000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 24.8,
#   'humidity': 75.0,
#   'pressure': 926.5,
#   'wind_direction': 81,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:06:25.854000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 24.8,
#   'humidity': 75.0,
#   'pressure': 926.6,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:07:25.870000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 25.0,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 188,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:08:25.851000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 25.2,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 137,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:09:25.871000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 25.3,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 331,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:10:25.898000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 25.4,
#   'humidity': 75.0,
#   'pressure': 926.5,
#   'wind_direction': 330,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:11:25.899000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.3,
#   'track_temperature': 25.3,
#   'humidity': 75.0,
#   'pressure': 926.5,
#   'wind_direction': 42,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:12:25.913000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.2,
#   'track_temperature': 25.3,
#   'humidity': 76.0,
#   'pressure': 926.4,
#   'wind_direction': 264,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:13:25.925000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 25.3,
#   'humidity': 75.0,
#   'pressure': 926.5,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:14:25.957000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.1,
#   'track_temperature': 25.1,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 171,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:15:25.944000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 25.1,
#   'humidity': 76.0,
#   'pressure': 926.5,
#   'wind_direction': 338,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:16:25.949000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 25.1,
#   'humidity': 77.0,
#   'pressure': 926.5,
#   'wind_direction': 207,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:17:25.971000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 77.0,
#   'pressure': 926.6,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:18:25.972000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 79.0,
#   'pressure': 926.4,
#   'wind_direction': 154,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:19:25.973000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 81.0,
#   'pressure': 926.4,
#   'wind_direction': 343,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:20:25.976000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 81.0,
#   'pressure': 926.4,
#   'wind_direction': 141,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:21:25.956000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 82.0,
#   'pressure': 926.3,
#   'wind_direction': 144,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:22:25.975000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 24.9,
#   'humidity': 83.0,
#   'pressure': 926.4,
#   'wind_direction': 149,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:23:25.974000+00:00',
#   'session_key': 9636,
#   'air_temperature': 22.0,
#   'track_temperature': 25.0,
#   'humidity': 83.0,
#   'pressure': 926.3,
#   'wind_direction': 291,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:24:25.989000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.9,
#   'track_temperature': 24.9,
#   'humidity': 85.0,
#   'pressure': 926.5,
#   'wind_direction': 189,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:25:25.975000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.9,
#   'track_temperature': 24.9,
#   'humidity': 85.0,
#   'pressure': 926.4,
#   'wind_direction': 23,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:26:25.976000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.9,
#   'track_temperature': 24.7,
#   'humidity': 85.0,
#   'pressure': 926.5,
#   'wind_direction': 353,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:27:26.016000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.8,
#   'track_temperature': 24.6,
#   'humidity': 86.0,
#   'pressure': 926.4,
#   'wind_direction': 353,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:28:26+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.7,
#   'track_temperature': 24.4,
#   'humidity': 86.0,
#   'pressure': 926.5,
#   'wind_direction': 21,
#   'meeting_key': 1249,
#   'wind_speed': 1.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:29:25.984000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.6,
#   'track_temperature': 24.2,
#   'humidity': 86.0,
#   'pressure': 926.6,
#   'wind_direction': 40,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:30:26.017000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.5,
#   'track_temperature': 24.1,
#   'humidity': 87.0,
#   'pressure': 926.6,
#   'wind_direction': 341,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:31:26.032000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.4,
#   'track_temperature': 24.0,
#   'humidity': 87.0,
#   'pressure': 926.6,
#   'wind_direction': 26,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:32:26.018000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.3,
#   'track_temperature': 24.0,
#   'humidity': 88.0,
#   'pressure': 926.6,
#   'wind_direction': 354,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:33:26.034000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.1,
#   'track_temperature': 23.8,
#   'humidity': 88.0,
#   'pressure': 926.7,
#   'wind_direction': 65,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:34:26.036000+00:00',
#   'session_key': 9636,
#   'air_temperature': 21.0,
#   'track_temperature': 23.5,
#   'humidity': 88.0,
#   'pressure': 926.6,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:35:26.034000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.9,
#   'track_temperature': 23.3,
#   'humidity': 89.0,
#   'pressure': 926.6,
#   'wind_direction': 332,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:36:26.033000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.8,
#   'track_temperature': 23.2,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 1,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:37:26.058000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.8,
#   'track_temperature': 23.3,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 8,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:38:26.063000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 23.7,
#   'humidity': 90.0,
#   'pressure': 926.6,
#   'wind_direction': 50,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:39:26.073000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 24.0,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 169,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:40:26.095000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.2,
#   'humidity': 89.0,
#   'pressure': 926.6,
#   'wind_direction': 227,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:41:26.091000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 275,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:42:26.080000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.6,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 320,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:43:26.079000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.7,
#   'humidity': 89.0,
#   'pressure': 926.5,
#   'wind_direction': 346,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:44:26.097000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.7,
#   'humidity': 89.0,
#   'pressure': 926.4,
#   'wind_direction': 143,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:45:26.095000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 24.7,
#   'humidity': 89.0,
#   'pressure': 926.4,
#   'wind_direction': 193,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:46:26.100000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.4,
#   'wind_direction': 218,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:47:26.097000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 89.0,
#   'pressure': 926.4,
#   'wind_direction': 212,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:48:26.114000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.0,
#   'humidity': 89.0,
#   'pressure': 926.4,
#   'wind_direction': 205,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:49:26.097000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.0,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 195,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:50:26.110000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 170,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:51:26.115000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.2,
#   'humidity': 89.0,
#   'pressure': 926.4,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:52:26.114000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 25.2,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:53:26.125000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 25.2,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 329,
#   'meeting_key': 1249,
#   'wind_speed': 1.3,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:54:26.127000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.1,
#   'wind_direction': 301,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T16:55:26.140000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 91.0,
#   'pressure': 926.3,
#   'wind_direction': 190,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:56:26.123000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 199,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:57:26.140000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.4,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 252,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:58:26.146000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.5,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 181,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T16:59:26.164000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.8,
#   'track_temperature': 25.5,
#   'humidity': 90.0,
#   'pressure': 926.3,
#   'wind_direction': 223,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:00:26.162000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.7,
#   'track_temperature': 25.4,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 191,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:01:26.163000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.7,
#   'track_temperature': 25.2,
#   'humidity': 89.0,
#   'pressure': 926.2,
#   'wind_direction': 257,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:02:26.163000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.2,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 220,
#   'meeting_key': 1249,
#   'wind_speed': 0.3,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:03:26.184000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.3,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 239,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:04:26.201000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.2,
#   'humidity': 90.0,
#   'pressure': 926.1,
#   'wind_direction': 236,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:05:26.224000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 279,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:06:26.229000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 301,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:07:26.233000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 91.0,
#   'pressure': 926.1,
#   'wind_direction': 181,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:08:26.231000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 926.2,
#   'wind_direction': 308,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:09:26.241000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 24.6,
#   'humidity': 91.0,
#   'pressure': 926.2,
#   'wind_direction': 205,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:10:26.230000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.3,
#   'humidity': 91.0,
#   'pressure': 926.2,
#   'wind_direction': 274,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:11:26.243000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.3,
#   'humidity': 91.0,
#   'pressure': 926.1,
#   'wind_direction': 278,
#   'meeting_key': 1249,
#   'wind_speed': 0.3,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:12:26.227000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.2,
#   'humidity': 92.0,
#   'pressure': 926.1,
#   'wind_direction': 97,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:13:26.241000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.3,
#   'humidity': 91.0,
#   'pressure': 926.1,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:14:26.244000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.3,
#   'humidity': 91.0,
#   'pressure': 926.1,
#   'wind_direction': 328,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:15:26.242000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.6,
#   'humidity': 91.0,
#   'pressure': 926.1,
#   'wind_direction': 226,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:16:26.235000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 90.0,
#   'pressure': 926.0,
#   'wind_direction': 258,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:17:26.251000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.7,
#   'humidity': 91.0,
#   'pressure': 926.0,
#   'wind_direction': 218,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:18:26.247000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.7,
#   'humidity': 91.0,
#   'pressure': 926.0,
#   'wind_direction': 168,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:19:26.255000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.8,
#   'humidity': 91.0,
#   'pressure': 926.0,
#   'wind_direction': 215,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:20:26.302000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 926.0,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:21:26.267000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.8,
#   'humidity': 91.0,
#   'pressure': 925.9,
#   'wind_direction': 189,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:22:26.267000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.8,
#   'humidity': 90.0,
#   'pressure': 925.8,
#   'wind_direction': 212,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:23:26.272000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.8,
#   'humidity': 90.0,
#   'pressure': 925.8,
#   'wind_direction': 12,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:24:26.284000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.8,
#   'humidity': 91.0,
#   'pressure': 925.8,
#   'wind_direction': 224,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:25:26.269000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 209,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:26:26.275000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 25.3,
#   'humidity': 90.0,
#   'pressure': 925.8,
#   'wind_direction': 156,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:27:26.500000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.3,
#   'humidity': 90.0,
#   'pressure': 925.8,
#   'wind_direction': 228,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:28:26.270000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.6,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 215,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:29:26.274000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.3,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 281,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:30:26.282000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.3,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 340,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:31:26.272000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.6,
#   'track_temperature': 25.1,
#   'humidity': 90.0,
#   'pressure': 925.8,
#   'wind_direction': 180,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 1},
#  {'date': '2024-11-03T17:32:26.277000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.7,
#   'track_temperature': 24.9,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 178,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:33:26.271000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.8,
#   'track_temperature': 24.9,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 198,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:34:26.288000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.7,
#   'track_temperature': 24.6,
#   'humidity': 89.0,
#   'pressure': 925.7,
#   'wind_direction': 166,
#   'meeting_key': 1249,
#   'wind_speed': 1.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:35:26.288000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.7,
#   'track_temperature': 24.6,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 199,
#   'meeting_key': 1249,
#   'wind_speed': 1.3,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:36:26.287000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 198,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:37:26.289000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.6,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 190,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:38:26.285000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.6,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:39:26.289000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.6,
#   'humidity': 89.0,
#   'pressure': 925.6,
#   'wind_direction': 162,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:40:26.289000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 925.7,
#   'wind_direction': 182,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:41:26.290000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.5,
#   'humidity': 90.0,
#   'pressure': 925.6,
#   'wind_direction': 237,
#   'meeting_key': 1249,
#   'wind_speed': 0.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:42:26.280000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.4,
#   'humidity': 89.0,
#   'pressure': 925.5,
#   'wind_direction': 158,
#   'meeting_key': 1249,
#   'wind_speed': 1.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:43:26.290000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.4,
#   'humidity': 89.0,
#   'pressure': 925.7,
#   'wind_direction': 180,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:44:26.291000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.4,
#   'humidity': 89.0,
#   'pressure': 925.7,
#   'wind_direction': 222,
#   'meeting_key': 1249,
#   'wind_speed': 1.2,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:45:26.293000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.5,
#   'humidity': 90.0,
#   'pressure': 925.6,
#   'wind_direction': 178,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:46:26.293000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.5,
#   'humidity': 90.0,
#   'pressure': 925.6,
#   'wind_direction': 312,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:47:26.292000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 925.5,
#   'wind_direction': 181,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:48:26.292000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.4,
#   'track_temperature': 24.7,
#   'humidity': 90.0,
#   'pressure': 925.5,
#   'wind_direction': 202,
#   'meeting_key': 1249,
#   'wind_speed': 1.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:49:26.303000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.6,
#   'humidity': 90.0,
#   'pressure': 925.5,
#   'wind_direction': 200,
#   'meeting_key': 1249,
#   'wind_speed': 0.9,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:50:26.295000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 89.0,
#   'pressure': 925.5,
#   'wind_direction': 337,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:51:26.311000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 90.0,
#   'pressure': 925.5,
#   'wind_direction': 140,
#   'meeting_key': 1249,
#   'wind_speed': 0.5,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:52:26.293000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 89.0,
#   'pressure': 925.6,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.6,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:53:26.312000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.5,
#   'humidity': 89.0,
#   'pressure': 925.5,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:54:26.293000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.2,
#   'humidity': 89.0,
#   'pressure': 925.5,
#   'wind_direction': 223,
#   'meeting_key': 1249,
#   'wind_speed': 0.0,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:55:26.294000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.1,
#   'humidity': 89.0,
#   'pressure': 925.5,
#   'wind_direction': 176,
#   'meeting_key': 1249,
#   'wind_speed': 1.1,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:56:26.294000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.0,
#   'humidity': 89.0,
#   'pressure': 925.4,
#   'wind_direction': 176,
#   'meeting_key': 1249,
#   'wind_speed': 1.8,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:57:26.313000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.0,
#   'humidity': 89.0,
#   'pressure': 925.4,
#   'wind_direction': 0,
#   'meeting_key': 1249,
#   'wind_speed': 0.7,
#   'rainfall': 0},
#  {'date': '2024-11-03T17:58:26.311000+00:00',
#   'session_key': 9636,
#   'air_temperature': 20.5,
#   'track_temperature': 24.1,
#   'humidity': 89.0,
#   'pressure': 925.4,
#   'wind_direction': 160,
#   'meeting_key': 1249,
#   'wind_speed': 0.4,
#   'rainfall': 0}]

# %% [markdown]
# ## 2. Data Exploration
# Now that we have relatively clean lap-by-lap data, weather aligned, we can begin to explore the strategy most teams adopted, and how they went.
