# %% [markdown]
# # pit-perfect
#
# The following builds a simple Monte Carlo model to assess how likely Nico's podium was and compare with other drivers.

# %% [markdown]
# ## 1. Monte Carlo method
#
# Monte Carlo simulations broadly describe XYZ based on random sampling in an effort
#
# In this context, we will be producing a few simulations of the race based on various factors in an effort to assess Nico's podium probability and if he had followed regular strategy.

# %% [markdown]
# ### 1.1. Preliminaries

# %%
# Imports

# %% [markdown]
# ## 1.2. Setup
#
# 1. Define domain of possible outputs
#     - Position, or DNF
# 2. Generate inputs randomly from a probability distribution over the domain
#     - Driver performance windows, reliability etc
# 3. Perform a deterministic computation of outputs
#     - Same conditions same results for particular simulation
# 4. Aggregate the results
#     - Produce final distribution of drivers positions/status
